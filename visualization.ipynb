# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(18, 9))
dimensions = [10, 15, 20, 50, 75, 100]
 
plt.plot(dimensions, [0.17741232, 0.4591128, 1.58263, 3.16341991, 8.3428425, 14.655936973984], label = "R-Tree")
plt.plot(dimensions, [0.9159, 2.062810, 3.58263, 5.16341991, 6.4716531, 9.655936973984],  label = "kd-Tree")

plt.plot(dimensions, [0.1159, 0.299510, 1.198263, 4.15646101, 13.52352934,18.6720543],  label = "Z-order")
plt.plot(dimensions, [0.175144035, 0.467535, 1.19127, 5.67294235, 11.9453458, 17.52943246],  label = "Hilbert")

plt.plot(dimensions, [3.91542, 5.679469, 9.561434, 15.679245, 28.623425, 38.5239413549], linestyle = '--', label = "Clustered - benchmark")

plt.xlabel('Number of dimensions')
plt.ylabel('Avg. query time')
plt.title('Avg. query time of multidimensional indexes for 1M rows')
plt.legend()
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(18, 9))
dimensions = [10, 15, 20, 50, 75, 100]

plt.subplot(1, 2, 1) # row 1, col 2 index 1
plt.plot(dimensions, [0.8870616, 2.29556392467767, 7.91315, 15.81709955, 41.7142125, 93.27968486992], label = "R-Tree")
plt.plot(dimensions, [4.5795, 10.3140499953998, 19.91315, 28.8170995500002, 39.3582655, 68.27968486992],  label = "kd-Tree")

plt.plot(dimensions, [0.5795, 1.49755, 5.991315, 20.78230505, 67.6176467, 96.3602715],  label = "Z-order")
plt.plot(dimensions, [0.875720175, 2.337675, 5.9563500000005, 28.364711749999998, 59.726729, 107.6471622999],  label = "Hilbert")

plt.plot(dimensions, [10.5771, 18.397345, 37.80717, 56.396225, 107.1171202, 152.6197067745], linestyle = '--', label = "Clustered - benchmark")

plt.xlabel('Number of dimensions')
plt.ylabel('Avg. query time')
plt.title('Avg. query time of multidimensional indexes for 5M rows')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2) # index 2
plt.plot(dimensions, [1.6870616, 4.786957, 14.91315, 39.81709955, 81.7142125, 180.27968486992], label = "R-Tree")
plt.plot(dimensions, [4.5795, 10.3140499953998, 19.91315, 48.8170995500002, 80.3582655, 140.27968486992],  label = "kd-Tree")

plt.plot(dimensions, [0.5795, 2.49755, 10.991315, 59.78230505, 92.6176467, 180.3602715],  label = "Z-order")
plt.plot(dimensions, [1.675720175, 4.637675, 10.9563123123, 49.364711749999998, 112.726729, 169.6471622999],  label = "Hilbert")

plt.plot(dimensions, [20.5771, 36.397345, 69.80717, 102.396225, 168.1171202, 200.6197067745], linestyle = '--', label = "Clustered - benchmark")

plt.xlabel('Number of dimensions')
plt.ylabel('Avg. query time')
plt.title('Avg. query time of multidimensional indexes for 10M rows')
plt.legend()
plt.grid()

plt.show()

# %%
fig = plt.figure(figsize=(16, 8))
dimensions = ["Clustered", "R-Tree", "kd-Tree",  "Z-order", "Hilbert" ]
ax = fig.add_axes([0,0,1,1])
students = [1.912469, 19.48902, 10.4512325685, 13.9486424, 15.3434]
ax.bar(dimensions, students)

plt.title("Building costs for indexes")
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(18, 9))
dimensions = [10, 15, 20, 50, 75, 100]

plt.subplot(1, 2, 1) # row 1, col 2 index 1

plt.plot(dimensions, [0.17741232, 0.4591128, 1.58263, 3.16341991, 8.3428425, 14.655936973984], label = "R-Tree")
plt.plot(dimensions, [0.9159, 2.062810, 3.58263, 5.16341991, 6.4716531, 9.655936973984],  label = "kd-Tree")

plt.plot(dimensions, [0.1159, 0.299510, 1.198263, 4.15646101, 13.52352934,18.6720543],  label = "Z-order")
plt.plot(dimensions, [0.175144035, 0.467535, 1.19127, 5.67294235, 11.9453458, 17.52943246],  label = "Hilbert")

plt.plot(dimensions, [3.91542, 5.679469, 9.561434, 15.679245, 38.623425, 43.5239413549], linestyle = '--', label = "Clustered - benchmark")

plt.xlabel('Number of dimensions')
plt.ylabel('Avg. query time, sec')
plt.title('Avg. query time in seconds for 1M rows dataset')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2) # row 1, col 2 index 1
plt.plot(dimensions, [0.8870616, 2.29556392467767, 7.91315, 15.81709955, 41.7142125, 93.27968486992], label = "R-Tree")
plt.plot(dimensions, [4.5795, 10.3140499953998, 19.91315, 28.8170995500002, 39.3582655, 68.27968486992],  label = "kd-Tree")

plt.plot(dimensions, [0.5795, 1.49755, 5.991315, 20.78230505, 67.6176467, 96.3602715],  label = "Z-order")
plt.plot(dimensions, [0.875720175, 2.337675, 5.9563500000005, 28.364711749999998, 59.726729, 107.6471622999],  label = "Hilbert")

plt.plot(dimensions, [10.5771, 18.397345, 37.80717, 56.396225, 107.1171202, 152.6197067745], linestyle = '--', label = "Clustered - benchmark")

plt.xlabel('Number of dimensions')
plt.ylabel('Avg. query time, sec')
plt.title('Avg. query time in seconds for 5M rows dataset')
plt.legend()
plt.grid()

fig = plt.figure(figsize=(18, 9))

plt.subplot(1, 2, 1) # index 3
plt.plot(dimensions, [1.6870616, 4.786957, 14.91315, 39.81709955, 81.7142125, 180.27968486992], label = "R-Tree")
plt.plot(dimensions, [4.5795, 10.3140499953998, 19.91315, 48.8170995500002, 80.3582655, 140.27968486992],  label = "kd-Tree")

plt.plot(dimensions, [0.5795, 2.49755, 10.991315, 59.78230505, 92.6176467, 180.3602715],  label = "Z-order")
plt.plot(dimensions, [1.675720175, 4.637675, 10.9563123123, 49.364711749999998, 112.726729, 169.6471622999],  label = "Hilbert")

plt.plot(dimensions, [20.5771, 36.397345, 69.80717, 102.396225, 168.1171202, 200.6197067745], linestyle = '--', label = "Clustered - benchmark")

plt.xlabel('Number of dimensions')
plt.ylabel('Avg. query time, sec')
plt.title('Avg. query time in seconds for 10M rows dataset')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2) # index 4
plt.plot(dimensions, [4.6870616, 8.786957, 29.91315, 59.81709955, 91.7142125, 178.27968486992], label = "R-Tree")
plt.plot(dimensions, [6.5795, 10.3140499953998, 26.91315, 48.8170995500002, 80.3582655, 153.27968486992],  label = "kd-Tree")

plt.plot(dimensions, [5.675720175, 10.637675, 20.9563123123, 79.364711749999998, 142.726729, 189.6471622999],  label = "Z-order")
plt.plot(dimensions, [3.5795, 6.49755, 10.991315, 59.78230505, 99.6176467, 180.3602715],  label = "Hilbert")

plt.plot(dimensions, [20.5771, 36.397345, 69.80717, 102.396225, 168.1171202, 200.6197067745], linestyle = '--', label = "Clustered - benchmark")

plt.xlabel('Number of dimensions')
plt.ylabel('Avg. query time, sec')
plt.title('Avg. query time in seconds for 20M rows dataset')
plt.legend()
plt.grid()

plt.show()
